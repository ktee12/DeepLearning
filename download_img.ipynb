# %% [markdown]
# <a href="https://colab.research.google.com/github/ktee12/DeepLearning/blob/main/download_img.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from fastbook import *
urls = search_images_ddg('grizzly bear', max_images=100)
len(urls),urls[0]
# Out:
# (100,
#  'https://2.bp.blogspot.com/-p-QKKk3T8O0/UQN3a5YSALI/AAAAAAAAFcE/iTlNg3jee9A/s1600/Grizzly+Bear-2013-0pic-03.jpg')

# %%
# !pip install fastbook

# %%
download_url(urls[0], 'images/bear.jpg')
im = Image.open('images/bear.jpg')
im.thumbnail((256,256))
im
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='303104' class='' max='296546' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       102.21% [303104/296546 00:00<00:00]
#     </div>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=256x161 at 0x7F2C3A2531D0>
